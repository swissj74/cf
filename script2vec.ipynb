# %% [markdown]
# # script2vec
# ## Why?
# The path a story takes in going from an idea to being an entertainment product that delights thousands, is not usually a straight path and often very iterative. Rights are bought, scripts written, and decisions made that flush out the story and turn it into the polished product we see on the silver screen
#
# Competition is fierce in the entertainment world and with today's short attention spans, capturing your audience is a must. And no amount of glimmer and noise will mask a bad story. Content is king even at the movies. It is easy to show that there is a relationship between dollars spend and dollars made. The more a movie is advertised, the more likely it will make money.
#
# Currently, out of 10 movies produced 1 will be a block-buster, 2 will fail, and the remainder more or less break even. And the one blockbuster makes up for both failures plus some. Our goal isn't to make every movie a hit, rather our goal is to move that needle a little bit because even a little bit better means millions more in revenue
#
#
# ## What
# In this algorithm, I am taking a look at scripts. Using deep learning I want to see if patterns can be discoverd in the language of the script that can help me move the needle
#
# ## How
#
# I will be using TensorFlow's word2vec to embed the words of each script in a vectorspace. In another module, I will be using deep learning algorithms and other machine learning algorithms to discover patterns in those embeddings. This will be based on https://github.com/tensorflow/tensorflow/blob/r0.11/tensorflow/examples/tutorials/word2vec/word2vec_basic.py
#
#
# ## What now (To Do)
# Use IMDB and other such data to draw a general picture of what features of a produced movie (minus the script) are important in determining success

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
filename = '../1_10 THINGS I HATE ABOUT YOU.txt.zip'

# %%
# Step 1 read the data into a list of strings.
def read_data(filename):
  """Extract the first text file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 18588

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 500

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
# del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 6012], ('the', 579), ('a', 434), ('to', 411), ('and', 336)]
# Sample data [0, 0, 5, 0, 0, 0, 0, 66, 0, 0] ['UNK', 'UNK', 'I', 'UNK', 'UNK', 'UNK', 'UNK', 'by', 'UNK', 'UNK']

# %%
len(words)
# Out:
# 18588

# %%
len(set(words))
# Out:
# 4849

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 0 UNK -> 5 I
# 0 UNK -> 0 UNK
# 5 I -> 0 UNK
# 5 I -> 0 UNK
# 0 UNK -> 5 I
# 0 UNK -> 0 UNK
# 0 UNK -> 0 UNK
# 0 UNK -> 0 UNK

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                     num_sampled, vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.initialize_all_variables()

# %%
# Step 5: Begin training.
num_steps = 1001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  104.764976501
# Nearest to INT.: sits, dress, right, FIELD, stares, So,, this?, wanted,
# Nearest to so: keep, Joey, guess, ask, Mrs., stands, Is, Have,
# Nearest to into: care, face., Cameron, AND, have, did, night, of,
# Nearest to we: me?, going., were, Patrick,, always, could, really, sister,
# Nearest to A: look, turns, eyes., Sarah, but, grabs, over, date,
# Nearest to but: party, know, went, I'm, That's, HOUSE, rises, out.,
# Nearest to not: STRATFORD, after, with, is, getting, Coffee, This, Patrick's,
# Nearest to sits: thinks, their, INT., after, chair, talk, several, dress,
# Nearest to MICHAEL: they, What's, turn, himself, OFFICE, hair, money, His,
# Nearest to don't: each, would, She's, CLUB, book, paint, every, (continuing;,
# Nearest to Bianca: hate, down, Your, right, toward, him, out, leave,
# Nearest to you're: go, of, Cameron., get, goes, him., --, thinks,
# Nearest to MANDELLA: We're, it, enters,, boys, keeps, So, lets, than,
# Nearest to get: mean, use, night, I'll, you're, Sharon, Bianca,, has,
# Nearest to by: were, jock, everyone, leans, I, out, Hey, black,
# Nearest to out: walk, His, Why, toward, by, who, Bianca, him.,
# Average loss at step  2000 :  4.9975031296
# Average loss at step  4000 :  3.75019448626
# Average loss at step  6000 :  3.64386076057
# Average loss at step  8000 :  3.59119272149
# Average loss at step  10000 :  3.55961395478
# Nearest to INT.: FIELD, they're, right, Mandella's, dress, DEREK, EXT., sits,
# Nearest to so: keep, ask, guess, Have, let, Joey, door,, stands,
# Nearest to into: night, through, to, care, have, face., of, AND,
# Nearest to we: were, really, you, ask, I, me?, could, sister,
# Nearest to A: but, look, eyes., How, Daddy,, Sarah, Forget, grabs,
# Nearest to but: party, A, know, rises, I'm, HOUSE, went, look,
# Nearest to not: is, after, STRATFORD, way, Mrs., Coffee, let, pretty,
# Nearest to sits: thinks, chair, their, heads, and, dress, several, after,
# Nearest to MICHAEL: WALTER, KAT, CAMERON, ', OFFICE, several, money, His,
# Nearest to don't: each, She's, would, way, every, were, CLUB, didn't,
# Nearest to Bianca: hate, Kat, Your, down, toward, him, Cameron, grins,
# Nearest to you're: I've, of, thinks, she's, way, says, goes, black,
# Nearest to MANDELLA: We're, lets, keeps, enters,, TEACHER, MRS., If, Ms.,
# Nearest to get: mean, use, think, night, see, Bianca,, hear, lets,
# Nearest to by: black, jock, leans, walks, out, hair, watch, own,
# Nearest to out: doing, onto, toward, His, UNK, by, OFFICE, few,
# Average loss at step  12000 :  3.54385078931
# Average loss at step  14000 :  3.53569008791
# Average loss at step  16000 :  3.52777887762
# Average loss at step  18000 :  3.51883275378
# Average loss at step  20000 :  3.51569206095
# Nearest to INT.: EXT., they're, FIELD, Mandella's, HOUSE, DEREK, right, sits,
# Nearest to so: keep, ask, let, door,, guess, Have, when, does,
# Nearest to into: through, to, night, Patrick,, most, Cameron, of, have,
# Nearest to we: were, you, I, ask, really, he, could, me?,
# Nearest to A: How, but, Daddy,, look, eyes., Forget, Sarah, CAFETERIA,
# Nearest to but: party, A, while, Sarah, rises, know, HOUSE, look,
# Nearest to not: way, after, is, STRATFORD, Mrs., let, pretty, Coffee,
# Nearest to sits: thinks, chair, heads, their, leans, walks, sit, and,
# Nearest to MICHAEL: WALTER, KAT, CAMERON, ', OFFICE, every, CLASS, Oh,,
# Nearest to don't: each, would, She's, didn't, every, were, way, might,
# Nearest to Bianca: Kat, Your, hate, down, several, toward, Patrick, grins,
# Nearest to you're: I've, she's, they're, thinks, of, way, black, hair,
# Nearest to MANDELLA: We're, MRS., TEACHER, keeps, enters,, lets, If, Ms.,
# Nearest to get: mean, see, think, use, night, hear, Bianca,, lets,
# Nearest to by: black, leans, walks, hair, jock, Mandella's, watch, THE,
# Nearest to out: onto, doing, OFFICE, toward, again,, sounds, few, His,
# Average loss at step  22000 :  3.51469327676
# Average loss at step  24000 :  3.51503303695
# Average loss at step  26000 :  3.50971425843
# Average loss at step  28000 :  3.507188169
# Average loss at step  30000 :  3.50374438226
# Nearest to INT.: EXT., HOUSE, FIELD, they're, DEREK, Mandella's, right, Kat.,
# Nearest to so: keep, ask, let, guess, door,, does, when, did,
# Nearest to into: to, through, night, Patrick,, most, table, Cameron, of,
# Nearest to we: you, ask, were, I, he, really, could, me?,
# Nearest to A: How, Daddy,, Forget, but, eyes., -, look, CAFETERIA,
# Nearest to but: party, A, while, Sarah, JOEY, look, moment, HOUSE,
# Nearest to not: way, after, is, Mrs., let, completely, STRATFORD, pretty,
# Nearest to sits: thinks, chair, heads, sit, leans, looks, walks, himself,
# Nearest to MICHAEL: WALTER, KAT, ', CAMERON, PATRICK, Oh,, OFFICE, CLASS,
# Nearest to don't: each, didn't, She's, would, were, every, might, way,
# Nearest to Bianca: Kat, Your, hate, several, Patrick, Walter, after, grins,
# Nearest to you're: she's, I've, they're, thinks, black, he's, hair, way,
# Nearest to MANDELLA: MRS., We're, TEACHER, keeps, enters,, Ms., lets, If,
# Nearest to get: mean, see, think, hear, night, lets, use, Bianca,,
# Nearest to by: black, leans, hair, walks, jock, high, watch, Mandella's,
# Nearest to out: onto, doing, OFFICE, again,, most, sounds, group, toward,
# Average loss at step  32000 :  3.50879503417
# Average loss at step  34000 :  3.50319714081
# Average loss at step  36000 :  3.50237188995
# Average loss at step  38000 :  3.49977910221
# Average loss at step  40000 :  3.49966969359
# Nearest to INT.: EXT., HOUSE, FIELD, they're, DEREK, Mandella's, Kat., breaks,
# Nearest to so: keep, ask, let, door,, guess, did, when, does,
# Nearest to into: to, through, Patrick,, night, most, table, Cameron, hair,
# Nearest to we: you, ask, were, I, he, really, could, me?,
# Nearest to A: How, Daddy,, Forget, eyes., -, OFFICE, Michael, CAFETERIA,
# Nearest to but: party, while, Sarah, A, moment, JOEY, look, If,
# Nearest to not: way, completely, let, Mrs., is, after, STRATFORD, several,
# Nearest to sits: heads, thinks, sit, looks, chair, leans, walks, stands,
# Nearest to MICHAEL: WALTER, KAT, PATRICK, CAMERON, ', Oh,, JOEY, OFFICE,
# Nearest to don't: didn't, each, would, She's, were, might, every, way,
# Nearest to Bianca: Kat, Your, Walter, several, after, Patrick, hate, grins,
# Nearest to you're: she's, they're, I've, thinks, black, he's, into, hair,
# Nearest to MANDELLA: MRS., TEACHER, We're, keeps, enters,, How, Ms., eyes.,
# Nearest to get: mean, see, think, hear, want, night, lets, of,
# Nearest to by: black, hair, leans, walks, jock, high, watch, Mandella's,
# Nearest to out: again,, doing, onto, OFFICE, most, keep, group, lets,
# Average loss at step  42000 :  3.50076844668
# Average loss at step  44000 :  3.50004490042
# Average loss at step  46000 :  3.49765579832
# Average loss at step  48000 :  3.49760861886
# Average loss at step  50000 :  3.49672895932
# Nearest to INT.: EXT., HOUSE, FIELD, they're, Mandella's, DEREK, PATRICK, breaks,
# Nearest to so: keep, ask, let, guess, door,, did, So, .,
# Nearest to into: to, through, Patrick,, table, most, night, Cameron, hair,
# Nearest to we: ask, you, were, I, he, really, could, me?,
# Nearest to A: How, Daddy,, OFFICE, Forget, -, eyes., Let's, CAFETERIA,
# Nearest to but: party, while, Sarah, moment, JOEY, If, jock, A,
# Nearest to not: completely, way, let, several, Mrs., trying, pretty, We,
# Nearest to sits: looks, heads, leans, sit, thinks, walks, stands, chair,
# Nearest to MICHAEL: WALTER, KAT, PATRICK, CAMERON, JOEY, PERKY, ', BIANCA,
# Nearest to don't: didn't, each, She's, would, might, were, every, did,
# Nearest to Bianca: Kat, Your, Walter, several, after, Patrick, grins, Joey,
# Nearest to you're: she's, they're, I've, thinks, black, he's, into, on,
# Nearest to MANDELLA: MRS., TEACHER, enters,, We're, keeps, JOEY, CAMERON, eyes.,
# Nearest to get: mean, see, want, think, hear, night, lets, have,
# Nearest to by: hair, black, leans, walks, jock, high, watch, Mandella's,
# Nearest to out: again,, onto, most, doing, OFFICE, keep, lets, group,
# Average loss at step  52000 :  3.49620622373
# Average loss at step  54000 :  3.49595801878
# Average loss at step  56000 :  3.49356860745
# Average loss at step  58000 :  3.49350117517
# Average loss at step  60000 :  3.49497387552
# Nearest to INT.: EXT., HOUSE, FIELD, DEREK, Mandella's, they're, PATRICK, breaks,
# Nearest to so: keep, ask, let, guess, did, ., So, door,,
# Nearest to into: to, through, Patrick,, table, most, night, you're, them,
# Nearest to we: ask, you, were, I, he, really, me?, could,
# Nearest to A: Daddy,, How, OFFICE, (to, -, Let's, Forget, CAFETERIA,
# Nearest to but: party, while, Sarah, moment, jock, JOEY, If, had,
# Nearest to not: completely, let, way, several, We, trying, Mrs., pretty,
# Nearest to sits: looks, heads, leans, sit, stands, walks, thinks, chair,
# Nearest to MICHAEL: WALTER, KAT, PATRICK, JOEY, PERKY, CAMERON, BIANCA, ',
# Nearest to don't: didn't, each, She's, would, might, were, did, every,
# Nearest to Bianca: Kat, Your, Walter, after, several, Patrick, Joey, grins,
# Nearest to you're: she's, they're, I've, thinks, he's, into, black, hair,
# Nearest to MANDELLA: MRS., TEACHER, JOEY, CAMERON, enters,, PATRICK, eyes., We're,
# Nearest to get: see, mean, want, think, hear, have, lets, night,
# Nearest to by: hair, black, walks, leans, high, jock, watch, of,
# Nearest to out: again,, most, onto, our, lets, keep, doing, food,
# Average loss at step  62000 :  3.49512141609
# Average loss at step  64000 :  3.49252872992
# Average loss at step  66000 :  3.49324677372
# Average loss at step  68000 :  3.49149469912
# Average loss at step  70000 :  3.49252463102
# Nearest to INT.: EXT., HOUSE, they're, Mandella's, DEREK, FIELD, breaks, PATRICK,
# Nearest to so: keep, ask, let, guess, So, did, ., enters,
# Nearest to into: through, to, Patrick,, table, most, you're, they're, night,
# Nearest to we: ask, you, were, I, he, really, me?, could,
# Nearest to A: OFFICE, Daddy,, How, The, Let's, CAFETERIA, (to, His,
# Nearest to but: party, while, Sarah, jock, had, moment, If, look,
# Nearest to not: completely, We, let, several, way, trying, Mrs., pretty,
# Nearest to sits: looks, leans, stands, sit, heads, smiles, walks, thinks,
# Nearest to MICHAEL: WALTER, KAT, PATRICK, PERKY, JOEY, CAMERON, BIANCA, CLASS,
# Nearest to don't: didn't, each, might, She's, did, would, were, if,
# Nearest to Bianca: Kat, Your, Walter, after, several, Joey, Patrick, tries,
# Nearest to you're: she's, they're, I've, thinks, into, he's, black, hair,
# Nearest to MANDELLA: MRS., TEACHER, CAMERON, JOEY, enters,, PATRICK, THE, eyes.,
# Nearest to get: want, think, see, have, mean, hear, take, lets,
# Nearest to by: hair, leans, black, walks, makes, high, jock, watch,
# Nearest to out: again,, most, our, onto, smiles., lets, Are, food,
# Average loss at step  72000 :  3.49226294672
# Average loss at step  74000 :  3.48944658756
# Average loss at step  76000 :  3.48959254611
# Average loss at step  78000 :  3.48702671444
# Average loss at step  80000 :  3.49160575759
# Nearest to INT.: EXT., HOUSE, they're, Mandella's, DEREK, PATRICK, breaks, FIELD,
# Nearest to so: keep, ask, guess, So, let, ., enters, did,
# Nearest to into: to, table, through, Patrick,, most, they're, them, you're,
# Nearest to we: ask, you, were, he, I, you've, really, could,
# Nearest to A: OFFICE, Daddy,, The, How, Let's, (to, CAFETERIA, His,
# Nearest to but: party, while, jock, Sarah, had, If, moment, look,
# Nearest to not: completely, We, let, trying, way, several, pretty, Mrs.,
# Nearest to sits: looks, stands, leans, heads, sit, smiles, walks, takes,
# Nearest to MICHAEL: WALTER, KAT, PATRICK, PERKY, JOEY, CAMERON, BIANCA, CLASS,
# Nearest to don't: didn't, each, might, did, would, She's, were, thought,
# Nearest to Bianca: Kat, Walter, Your, after, several, Joey, Patrick, tries,
# Nearest to you're: she's, they're, I've, thinks, he's, into, again,, black,
# Nearest to MANDELLA: MRS., TEACHER, CAMERON, JOEY, enters,, THE, PATRICK, eyes.,
# Nearest to get: want, think, have, see, hear, take, mean, make,
# Nearest to by: hair, leans, black, walks, makes, high, jock, new,
# Nearest to out: our, most, again,, Are, lets, smiles., onto, can,
# Average loss at step  82000 :  3.48675796616
# Average loss at step  84000 :  3.48986536729
# Average loss at step  86000 :  3.48830671883
# Average loss at step  88000 :  3.48751596582
# Average loss at step  90000 :  3.48952134025
# Nearest to INT.: EXT., HOUSE, PATRICK, they're, Mandella's, DEREK, breaks, when,
# Nearest to so: keep, ask, So, ., guess, did, let, enters,
# Nearest to into: to, table, Patrick,, through, most, they're, them, you're,
# Nearest to we: ask, you, I, he, were, know, you've, could,
# Nearest to A: OFFICE, The, Let's, Daddy,, How, (to, CAFETERIA, His,
# Nearest to but: party, while, jock, had, Sarah, If, moment, look,
# Nearest to not: completely, We, let, trying, gonna, way, several, pretty,
# Nearest to sits: looks, stands, leans, heads, sit, smiles, takes, stops,
# Nearest to MICHAEL: WALTER, KAT, PATRICK, JOEY, PERKY, CAMERON, BIANCA, CLASS,
# Nearest to don't: didn't, each, did, might, would, She's, were, could,
# Nearest to Bianca: Kat, Walter, after, Your, several, Joey, Patrick, tries,
# Nearest to you're: she's, they're, thinks, I've, again,, he's, into, black,
# Nearest to MANDELLA: MRS., TEACHER, CAMERON, JOEY, PATRICK, eyes., THE, enters,,
# Nearest to get: want, have, think, see, take, make, hear, mean,
# Nearest to by: hair, makes, black, high, leans, walks, jock, hands,
# Nearest to out: our, Are, most, smiles., can, onto, again,, lets,
# Average loss at step  92000 :  3.48785752559
# Average loss at step  94000 :  3.487305897
# Average loss at step  96000 :  3.48728286409
# Average loss at step  98000 :  3.48762712514
# Average loss at step  100000 :  3.48919234753
# Nearest to INT.: EXT., HOUSE, they're, PATRICK, DEREK, Mandella's, talk, Well,,
# Nearest to so: keep, ask, So, ., guess, Oh,, did, let,
# Nearest to into: table, to, through, Patrick,, most, they're, them, Coffee,
# Nearest to we: ask, you, I, were, he, you've, know, could,
# Nearest to A: OFFICE, Let's, The, Daddy,, CAFETERIA, How, (to, His,
# Nearest to but: party, while, had, jock, Sarah, If, moment, look,
# Nearest to not: completely, trying, We, let, gonna, several, way, beautiful,
# Nearest to sits: looks, stands, leans, sit, heads, smiles, takes, stops,
# Nearest to MICHAEL: WALTER, KAT, PATRICK, PERKY, JOEY, CAMERON, CLASS, BIANCA,
# Nearest to don't: didn't, each, might, did, would, could, thought, She's,
# Nearest to Bianca: Kat, Walter, after, several, Your, Joey, Patrick, sounds,
# Nearest to you're: she's, they're, he's, thinks, again,, I'm, I've, black,
# Nearest to MANDELLA: MRS., CAMERON, TEACHER, PATRICK, JOEY, eyes., THE, HALLWAY,
# Nearest to get: want, have, take, think, see, make, hear, be,
# Nearest to by: makes, hair, high, black, leans, walks, new, jock,
# Nearest to out: Are, our, smiles., most, can, chair, lets, onto,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
